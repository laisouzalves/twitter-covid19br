# %% [markdown]
# # Twitter Sentiment Analysis (Parte 1)
#
# A construção da rede neural, que vou utilizar na parte 2, foi baseada em uma aula que tive da Udacity, do "PyThorch Scholarship Challenge", no qual aprendi sobre redes neurais profundas (CNNs, LSTMs, etc.).
#
# O meu objetivo nessa primeira parte vai fazer uma análise exploratória dos dados pra então treinar um algoritmo, na parte 2, capaz de classificar os sentimentos desses twittes, que são dividos em três categorias, sendo elas:
#
# 1 - Negativos: qualquer tuíte relacionado com algum sentimento ruim, negativo, de estresse, ou que sejam contra a quarentena;
#
# 2 - Neutros: caem nessa categoria os tts de propaganda, os que tem um sentimento neutro em relação a quarentena, relatos de atividades cotidianas;
#
# 3 - Positivos: expressam um sentimento positivo em relação a quarentena, ou piadas, brincadeiras, dicas, etc.
#
# Também influenciou a minha nota quando um determinado tuíte aparentava que seu autor poderia vir logo a aparentar sintomas negativos, relacionados ao tédio de ter que ficar em casa.

# %%
import re
from baseuf import ufbr
from collections import Counter
import csv
import seaborn as sns; sns.set()
import matplotlib.pyplot as plt
import pandas as pd

# %% [markdown]
# ## Informações básicas sobre os dados

# %%
# Abrindo os arquivos:
csvFile = str(input(">>> Enter file name: "))
data = pd.read_csv(csvFile)
# Out:
# >>> Enter file name: lais.csv

# %%
data.head()
# Out:
#    id                      created_at  \
# 0   1  Thu Mar 19 23:46:46 +0000 2020
# 1   2  Thu Mar 19 23:46:36 +0000 2020
# 2   3  Thu Mar 19 23:46:34 +0000 2020
# 3   4  Thu Mar 19 23:46:14 +0000 2020
# 4   5  Thu Mar 19 23:46:11 +0000 2020
#
#                                        original_text original_author  \
# 0  Aproveite a quarentena e assista o Clíp do @Bl...  diegonogueira8
# 1  #jabá #resenha #blogues Quer uma #indicação de...    ticseducacao
# 2  Sr. Presidente @jairbolsonaro, o senhor já pod...      Nelson_MCZ
# 3  Vendo uma série para esquecer um pouco todo es...    jacksonjpsdb
# 4  #FiqueEmCasa - Uma campanha CartaCapital https...   paulobretasjr
#
#                                             hashtags                   place  \
# 0  FakeNews, quarentena, coronavirus, coronavirus...        São Paulo/Brazil
# 1  jabá, resenha, blogues, indicação, livro, quar...  Rio de Janeiro, Brasil
# 2                                         quarentena                  Brasil
# 3                                         Quarentena   Teresina Piauí Brasil
# 4                                        FiqueEmCasa          Rio de Janeiro
#
#                               place_coord_boundaries has_place   is_rt  \
# 0  [[-46.826039, -24.008814], [-46.365052, -24.00...      True  False
# 1                                                NaN      True  False
# 2                                                NaN      True  False
# 3                                                NaN      True  False
# 4                                                NaN      True  False
#
#    sentiment_lais sentiment_label_lais sentiment_label_luis  \
# 0               2              neutral             negative
# 1               2              neutral             positive
# 2               1             negative             negative
# 3               1             negative             negative
# 4               3             positive              neutral
#
#    sentiment_score_luis sentiment_label_google  sentiment_score_google
# 0                  0.60               positive                     0.4
# 1                  0.97               positive                     0.2
# 2                  0.66               positive                     0.3
# 3                  0.98               negative                    -0.2
# 4                  0.97               positive                     0.2

# %% [markdown]
# # "Little" Exploratory Data Analysis (EDA)

# %%
total_twittes = data.shape[0]
print("O total de twittes é de {}.".format(total_twittes))
# Out:
# O total de twittes é de 10886.

# %% [markdown]
# ## Quantos Locais válidos únicos existem

# %%
accent_map = {u'\u00c0': u'A', u'\u00c1': u'A', u'\u00c2': u'A', u'\u00c3': u'A', u'\u00c4': u'A', u'\u00c5': u'A', u'\u00c6': u'A', u'\u00c7': u'C', u'\u00c8': u'E', u'\u00c9': u'E', u'\u00ca': u'E', u'\u00cb': u'E', u'\u00cc': u'I', u'\u00cd': u'I', u'\u00ce': u'I', u'\u00cf': u'I', u'\u00d0': u'D', u'\u00d1': u'N', u'\u00d2': u'O', u'\u00d3': u'O', u'\u00d4': u'O', u'\u00d5': u'O', u'\u00d6': u'O', u'\u00d7': u'x', u'\u00d8': u'0', u'\u00d9': u'U', u'\u00da': u'U', u'\u00db': u'U', u'\u00dc': u'U', U'\u00dd': u'Y', u'\u00df': u'B', u'\u00e0': u'a', u'\u00e1': u'a', u'\u00e2': u'a', u'\u00e3': u'a', u'\u00e4': u'a', u'\u00e5': u'a', u'\u00e6': u'a', u'\u00e7': u'c', u'\u00e8': u'e', u'\u00e9': u'e', u'\u00ea': u'e', u'\u00eb': u'e', u'\u00ec': u'i', u'\u00ed': u'i', u'\u00ee': u'i', u'\u00ef': u'i', u'\u00f1': u'n', u'\u00f2': u'o', u'\u00f3': u'o', u'\u00f4': u'o', u'\u00f5': u'o', u'\u00f6': u'o', u'\u00f8': u'0', u'\u00f9': u'u', u'\u00fa': u'u', u'\u00fb': u'u', u'\u00fc': u'u'}


def accent_remove(m):
    return accent_map[m.group(0)]


def clean_list(list_to_clean):
    for idx, item in enumerate(list_to_clean):
        list_to_clean[idx] = str(item)
        string = list_to_clean[idx]
        list_to_clean[idx] = re.sub('[÷ð]', '', string)
        string = list_to_clean[idx]
        list_to_clean[idx] = re.sub(u'([\u00C0-\u00FC])', accent_remove, string.encode().decode('utf-8'))
        list_to_clean[idx] = list_to_clean[idx].lower()
        string = list_to_clean[idx]
        list_to_clean[idx] = re.sub('\W\s-', '', string)
        string = list_to_clean[idx]
        list_to_clean[idx] = re.sub('[…•\(\)\&]', ' ', string)
    return list_to_clean


def remove_emoji(string):
    emoji_pattern = re.compile("["
                           u"\U0001F600-\U0001F64F"  # emoticons
                           u"\U0001F300-\U0001F5FF"  # symbols & pictographs
                           u"\U0001F680-\U0001F6FF"  # transport & map symbols
                           u"\U0001F1E0-\U0001F1FF"  # flags (iOS)
                           u"\U00002702-\U000027B0"
                           u"\U000024C2-\U0001F251"
                           "]+", flags=re.UNICODE)
    return emoji_pattern.sub(r'', string)


def clean_tts(list_to_clean):
    for idx, item in enumerate(list_to_clean):
        # transforma tudo para str
        list_to_clean[idx] = str(item)
        # retira todo o link https:// do tuite
        list_str = list_to_clean[idx].split()
        string = ' '.join([word for word in list_str if not re.search('https://t.co', word)])
        #remove acentos
        list_to_clean[idx] = re.sub(u'([\u00C0-\u00FC])', accent_remove, string.encode().decode('utf-8'))
        # remove emojis
        string = list_to_clean[idx].encode('ascii', 'ignore').decode('ascii')
        list_to_clean[idx] = remove_emoji(string)
        # deixa tudo em caixa baixa
        list_to_clean[idx] = list_to_clean[idx].lower()
        # substitui o restante dos caracteres desnecessarios
        string = list_to_clean[idx]
        list_to_clean[idx] = re.sub('[…•\(\)\&]', '', string)
        string = list_to_clean[idx]
        list_to_clean[idx] = re.sub('\W\s-', '', string)
        string = list_to_clean[idx]
        list_to_clean[idx] = re.sub('["º°/_]', ' ', string)
        # remove espaços desnecessarios
        string_list = list_to_clean[idx].split()
        list_to_clean[idx] = ' '.join(string_list)

    return list_to_clean

def filter_count(principal_list, filter1):
    count_filter = 0
    bool_list = []
    for idx, item in enumerate(principal_list):
        frase = item
        if ' - ' in frase:
            frase = frase.split(' - ')
        elif ' -' in frase:
            frase = frase.split(' -')
        elif '- ' in frase:
            frase = frase.split('- ')
        elif '-' in frase:
            frase = frase.split('-')
        elif ' / ' in frase:
            frase = frase.split(' / ')
        elif ' /' in frase:
            frase = frase.split(' /')
        elif '/ ' in frase:
            frase = frase.split('/ ')
        elif '/' in frase:
            frase = frase.split('/')
        elif ' , ' in frase:
            frase = frase.split(' , ')
        elif ', ' in frase:
            frase = frase.split(', ')
        elif ' ,' in frase:
            frase = frase.split(' ,')
        elif ',' in frase:
            frase = frase.split(',')
        elif ' | ' in frase:
            frase = frase.split(' | ')
        elif ' |' in frase:
            frase = frase.split(' |')
        elif '| ' in frase:
            frase = frase.split('| ')
        elif '|' in frase:
            frase = frase.split('|')
        
        if type(frase) != list:
            frase = [frase]
            
        for idx, item in enumerate(filter1):
            if item in frase:
                count_filter += 1
                bool_list.append(True)
                break
            if item == filter1[-1]:
                bool_list.append(False)

    return count_filter, bool_list


# def cities_tolist(city_list):
#     cities = []
#     for idx, item in enumerate(city_list):
#         city = item.lower()
#         cities.append(city)
#     return cities


estados = [['acre', 'ac'], ['alagoas', 'al'], ['amazonas', 'am'], ['amapa', 'ap'], ['bahia', 'bahea', 'ba'],  ['ceara', 'ce'], ['distrito federal', 'de-efe', 'brasolia', 'df', 'taguatinga', 'asa sul', 'sobradinho', 'ceilandia', 'samambaia', 'asa norte', 'guara', 'aguas claras', 'parkway', 'vicente pires'], ['espirito santo', 'es'], ['goias', 'gyn', 'go'], ['maranhao', 'terehell', 'ma'], ['minas gerais', 'mg'], ['mato grosso do sul', 'ms'], ['mato grosso', 'mt'], ['para', 'pa'], ['paraiba', 'pb'], ['pernambuco', 'pe'], ['piaui', 'pi'], ['parana', 'pr'], ['rio de janeiro', 'rj'], ['rio grande do norte', 'rn'], ['rondonia', 'ro'], ['roraima', 'rr'], ['rio grande do sul', 'rs'], ['santa catarina', 'sc'], ['sergipe', 'se'], ['sao paulo', 'sampa', 'sp'], ['tocantins', 'to']]

def separar_estados(lista_locais, csvFile_):
    c_lista_locais = clean_list(lista_locais)
    dataframe = pd.DataFrame(columns=['state', 'tts_count'])
    # ufbr.list_uf = ['AC', 'AL', 'AM', 'AP', 'BA', 'CE', 'DF', 'ES', 'GO', 'MA', 'MG', 'MS', 'MT', 'PA', 'PB', 'PE', 'PI', 'PR', 'RJ', 'RN', 'RO', 'RR', 'RS', 'SC', 'SE', 'SP', 'TO']
    for idx, item in enumerate(ufbr.list_uf):
        # Example: cidades_sp = ufbr.list_cidades('SP')
        # cities_tolist() limpa a lista de cidades (set lower)
        # cities = cities_tolist(ufbr.list_cidades(item)) + estados[idx]
        cities = [x.lower() for x in ufbr.list_cidades(item)] + estados[idx]
        # c_cities contains the list of cities without any pontuation
        c_cities = clean_list(cities)
        # cities_count(states_list) é o numero de tweets na lista states_list
        cities_count, has_place_list = filter_count(c_lista_locais, c_cities)
        row_to_append = [str(item), cities_count]
        row = pd.DataFrame([row_to_append], columns=['state', 'tts_count'])
        dataframe = dataframe.append(row, ignore_index=True)

    dataframe.to_csv(csvFile_, mode='a', columns=['state', 'tts_count'], header=True, index=False, encoding="utf-8")

# %% [raw]
# # lista_teste = ['carrao, sao paulo', 'banana, sp/brasil', 'brasil - bsb/sp', 'moto nada a ver']
# filtro_teste = ['sao paulo', 'brasil', 'bsb', 'sp']
# filter_count(lista_teste, filtro_teste)

# %%
estados_list = ['acre', 'ac', 'alagoas', 'al', 'amapa', 'ap', 'amazonas', 'am', 'bahia', 'ba', 'ceara', 'ce', 'distrito federal', 'df', 'espirito santo', 'es', 'goias', 'go', 'maranhao', 'ma', 'mato grosso', 'mt', 'mato grosso do sul', 'ms', 'minas gerais', 'mg', 'para', 'pa', 'paraiba', 'pb', 'parana', 'pr', 'pernambuco', 'pe', 'piaui', 'pi', 'rio de janeiro', 'rj', 'rio grande do norte', 'rn', 'sul', 'rs', 'rondonia', 'ro', 'roraima', 'rr', 'santa catarina', 'sc', 'sao paulo', 'sp', 'sergipe', 'se', 'tocantins', 'to']

capitais = ['rio branco', 'maceio', 'macapa', 'manaus', 'salvador', 'fortaleza', 'brasilia', 'bsb', 'vitoria', 'goiania', 'gyn', 'sao luis', 'cuiaba', 'campo grande', 'belo horizonte', 'bh', 'belem', 'joao pessoa', 'jp', 'curitiba', 'recife', 'teresina', 'terehell', 'rio de janeiro', 'rj', 'natal', 'porto alegre', 'poa', 'porto velho', 'boa vista', 'florianopolis', 'floripa', 'sao paulo', 'sampa', 'aracaju', 'palmas']

print("Colecting all cities in Brasil...")
all_cities = []
for item in ufbr.list_uf:
    city_list = [x.lower() for x in ufbr.list_cidades(item)]
    all_cities += city_list
print("Done colecting all cities.\n")

# all_cities = []    
# for idx, item in enumerate(ufbr.list_uf):
#     city_list = cities_tolist(ufbr.list_cidades(item))
#     for idx, item in enumerate(city_list):
#         all_cities.append(item)

print("Cleaning lists...")
locais_br = all_cities + estados_list + ['brasil', 'brazil']
c_locais_br = clean_list(locais_br)

places = data['place'].to_list()
c_places = clean_list(places)
print("Done cleaning lists.\n")

# places_idx = []
# places_bool = []
# for idx, item in enumerate(c_places):
#     string = str(item)
#     for i, j in enumerate(string.split()): 
#         if j in c_locais_br:
#             places_bool.append(True)
#             places_idx.append(idx)
#             break
#         else: 
#             places_bool.append(False)
#
# OU ESSA VERSÃO ABAIXO QUE É MAIS EFICIENTE
#
# print("Colecting 'has_place' column...")
# places_bool = [True if item in c_locais_br else False for item in c_places]
# print("Done colecting 'has_place' column. /nNow colecting places indexes...")
# places_idx = [idx for idx, item in enumerate(c_places) if item in c_locais_br]
# print("Done colecting places indexes.")

# Mas melhor ainda é o código abaixo. Eu corrigi a funçao filter_count() pra coletar a coluna True/False
print("Colecting 'has_place' column...")
num_places_br, has_place = filter_count(c_places, c_locais_br)
print("Done colecting 'has_place' column.")

mask = data['place'].notnull()
data_all_places = data[mask]

print("Número total de tweets com local preenchido {}.\nIsso equivale a {:.2f} % dos tweets.\n".format(data_all_places.shape[0], data_all_places.shape[0]*100/data.shape[0]))

# print("Número total de twittes que possuem local válido: {}.\nIsso equivale à {:.2f}% do total de twittes.".format(len(places_idx), len(places_idx)*100/len(c_places)))
print("Número total de twittes que possuem local válido: {}.\nIsso equivale à {:.2f}% do total de twittes.".format(num_places_br, num_places_br*100/data.shape[0]))
# Out:
# Colecting all cities in Brasil...
# Done colecting all cities.
#
# Cleaning lists...
# Done cleaning lists.
#
# Colecting 'has_place' column...
# Done colecting 'has_place' column.
# Número total de tweets com local preenchido 10875.
# Isso equivale a 99.90 % dos tweets.
#
# Número total de twittes que possuem local válido: 9497.
# Isso equivale à 87.24% do total de twittes.

# %% [raw]
# c_places[:50]

# %% [raw]
# str_teste = 'sao paulo  ,    brasil'
# print(str_teste)
# str_arrumada = str_teste.split()
# print(str_arrumada)
# str_arrumada = ' '.join(str_arrumada)
# print(str_arrumada)

# %%
data.drop(columns=['has_place'], inplace=True)

# %%
# O código abaixo já não é mais necessário pq essa funcionalidade foi inserida na função filter_count()
# has_place = list(range(0, len(data['place'])))
# for idx,item in enumerate(data['place']):
#     if idx in places_idx:
#         has_place[idx] = True
#     else:
#         has_place[idx] = False


has_place = pd.DataFrame(has_place, columns=['has_place'])
new_data = pd.concat([data, has_place], axis=1)
print(">>> New column 'has_place' has been concatenated")
try:
    if new_data['Unnamed: 0'].any():
        print('---------------------------------------------------------')
        print("Droping column 'Unnamed: 0'")
        new_data.drop(columns=['Unnamed: 0'], inplace=True)
except KeyError:
    pass
# Out:
# >>> New column 'has_place' has been concatenated

# %%
new_data.head(50)
# Out:
#     id                      created_at  \
# 0    1  Thu Mar 19 23:46:46 +0000 2020
# 1    2  Thu Mar 19 23:46:36 +0000 2020
# 2    3  Thu Mar 19 23:46:34 +0000 2020
# 3    4  Thu Mar 19 23:46:14 +0000 2020
# 4    5  Thu Mar 19 23:46:11 +0000 2020
# 5    6  Thu Mar 19 23:45:40 +0000 2020
# 6    7  Thu Mar 19 23:45:38 +0000 2020
# 7    8  Thu Mar 19 23:44:45 +0000 2020
# 8    9  Thu Mar 19 23:44:31 +0000 2020
# 9   10  Thu Mar 19 23:44:25 +0000 2020
# 10  11  Thu Mar 19 23:44:20 +0000 2020
# 11  12  Thu Mar 19 23:44:17 +0000 2020
# 12  13  Thu Mar 19 23:44:01 +0000 2020
# 13  14  Thu Mar 19 23:43:59 +0000 2020
# 14  15  Thu Mar 19 23:43:45 +0000 2020
# 15  16  Thu Mar 19 23:43:44 +0000 2020
# 16  17  Thu Mar 19 23:43:36 +0000 2020
# 17  18  Thu Mar 19 23:43:19 +0000 2020
# 18  19  Thu Mar 19 23:42:52 +0000 2020
# 19  20  Thu Mar 19 23:42:48 +0000 2020
# 20  21  Thu Mar 19 23:42:44 +0000 2020
# 21  22  Thu Mar 19 23:42:40 +0000 2020
# 22  23  Thu Mar 19 23:42:37 +0000 2020
# 23  24  Thu Mar 19 23:42:35 +0000 2020
# 24  25  Thu Mar 19 23:42:32 +0000 2020
# 25  26  Thu Mar 19 23:42:22 +0000 2020
# 26  27  Thu Mar 19 23:42:08 +0000 2020
# 27  28  Thu Mar 19 23:42:00 +0000 2020
# 28  29  Thu Mar 19 23:41:57 +0000 2020
# 29  30  Thu Mar 19 23:41:49 +0000 2020
# 30  31  Thu Mar 19 23:41:48 +0000 2020
# 0                    São Paulo/Brazil
# 1              Rio de Janeiro, Brasil
# 2                              Brasil
# 3               Teresina Piauí Brasil
# 4                      Rio de Janeiro
# 5                   Fortaleza, Brasil
# 6                          RJ, Brasil
# 7                    Salvador, Brasil
# 8              Rio de Janeiro, Brasil
# 9                 Boa Vista/RR-Brasil
# 10        Av Angelica 2491, 14o andar
# 11      São Bernardo do Campo, Brasil
# 12             Belo Horizonte, Brasil
# 13                           Natal/RN
# 14            Brazil - Rio de Janeiro
# 15                             Brasil
# 16              Florianópolis, Brasil
# 17                     Ilhéus, Brasil
# 18                          São Paulo
# 19     Av.Campos Sáles, 1625 - Centro
# 20                   Fonseca, Niterói
# 21                    Vitória, Brazil
# 22                             Brasil
# 23            Buenos Aires, Argentina
# 24      São Bernardo do Campo, Brasil
# 25             Rio de Janeiro, Brasil
# 26                  São Paulo, Brasil
# 27                    Recife - Brazil
# 28                  Fortaleza, Brasil
# 29  RS, Centro-Oeste e Norte - Brasil
# 30             Belo Horizonte, Brasil
# 31                     São Paulo - SP
# 32                    Ibirité, Brasil
# 33                             Brasil
# 34               Brazil, São Paulo/SP
# 35                     Rio De Janeiro
# 36                   Fortaleza, Ceará
# 37            Rio de Janeiro, Brasil
# 38              Santo André-SP-Brasil
# 39                Jaguariúna / Brasil
# 40                  Blumenau/SC - BRA
# 41                          São Paulo
# 42                      Serra, Brasil
# 43                             Brasil
# 44                  Sao Paulo, Brazil
# 45             Belo Horizonte, Brasil
# 46         Rio de Janeiro, RJ, Brasil
# 47                         Garanhuns
# 48              São Paulo, SP, Brasil
# 49                     Palmas, Brazil
#
#                                place_coord_boundaries   is_rt  sentiment_lais  \
# 0   [[-46.826039, -24.008814], [-46.365052, -24.00...  False                2
# 1                                                 NaN  False                2
# 2                                                 NaN  False                1
# 3                                                 NaN  False                1
# 4                                                 NaN  False                3
# 5                                                 NaN  False                2
# 6                                                 NaN  False                3
# 7                                                 NaN  False                1
# 8                                                 NaN  False                2
# 9                                                 NaN  False                1
# 10                                                NaN  False                2
# 11                                                NaN  False                2
# 12                                                NaN  False                1
# 13                                                NaN  False                2
# 14                                                NaN  False                3
# 15  [[-46.826039, -24.008814], [-46.365052, -24.00...  False                3
# 16                                                NaN  False                2
# 17                                                NaN  False                3
# 18  [[-46.826039, -24.008814], [-46.365052, -24.00...  False                3
# 19                                                NaN  False                3
# 20                                                NaN  False                3
# 21                                                NaN  False                1
# 22                                                NaN  False                3
# 23                                                NaN  False                2
# 24                                                NaN  False                3
# 25                                                NaN  False                3
# 26                                                NaN  False                2
# 27                                                NaN  False                3
# 28  [[-38.638212, -3.88818], [-38.401568, -3.88818...  False                3
# 29                                                NaN  False                3
# 30                                                NaN  False                1
# 31                                                NaN  False                2
# 32                                                NaN  False                2
# 33                                                NaN  False                3
# 34                                                NaN  False                3
# 35                                                NaN  False                3
# 36                                                NaN  False                2
# 37  [[-43.795449, -23.08302], [-43.0877068, -23.08...  False                1
# 38  [[-46.826039, -24.008814], [-46.365052, -24.00...  False                3
# 39  [[-47.102118, -22.750218], [-46.93054, -22.750...  False                3
# 40                                                NaN  False                3
# 41                                                NaN  False                3
# 42                                                NaN  False                3
# 43                                                NaN  False                2
# 44                                                NaN  False                3
# 45                                                NaN  False                2
# 46  [[-43.795449, -23.08302], [-43.0877068, -23.08...  False                2
# 47  [[-36.9482256, -8.670601], [-36.542507, -8.670...  False                3
# 48                                                NaN  False                3
# 49                                                NaN  False                3
#
#    sentiment_label_lais sentiment_label_luis  sentiment_score_luis  \
# 0               neutral             negative                  0.60
# 1               neutral             positive                  0.97
# 2              negative             negative                  0.66
# 3              negative             negative                  0.98
# 4              positive              neutral                  0.97
# 5               neutral              neutral                  0.86
# 6              positive             negative                  0.64
# 7              negative              neutral                  0.83
# 8               neutral              neutral                  0.61
# 9              negative              neutral                  0.72
# 10              neutral             negative                  0.74
# 11              neutral             positive                  0.51
# 12             negative              neutral                  0.81
# 13              neutral              neutral                  0.69
# 14             positive              neutral                  0.83
# 15             positive              neutral                  0.85
# 16              neutral              neutral                  0.72
# 17             positive              neutral                  0.90
# 18             positive             positive                  0.92
# 19             positive             positive                  0.96
# 20             positive             negative                  0.76
# 21             negative             negative                  0.89
# 22             positive             negative                  0.93
# 23              neutral              neutral                  0.72
# 24             positive              neutral                  0.93
# 25             positive              neutral                  0.74
# 26              neutral             positive                  0.91
# 27             positive             negative                  0.96
# 28             positive             negative                  0.91
# 29             positive             negative                  0.48
# 30             negative             positive                  0.96
# 31              neutral             negative                  0.92
# 32              neutral              neutral                  0.59
# 33             positive              neutral                  0.93
# 34             positive             negative                  0.94
# 35             positive             negative                  0.56
# 36              neutral              neutral                  0.78
# 37             negative             negative                  0.93
# 38             positive                mixed                 -1.00
# 39             positive             positive                  0.80
# 40             positive             positive                  0.92
# 41             positive             negative                  0.72
# 42             positive             negative                  0.88
# 43              neutral             negative                  0.44
# 44             positive              neutral                  0.90
# 45              neutral             positive                  0.99
# 46              neutral              neutral                  0.67
# 47             positive             negative                  0.74
# 48             positive              neutral                  0.93
# 49             positive             negative                  0.64
#
#    sentiment_label_google  sentiment_score_google  has_place
# 0                positive                     0.4       True
# 1                positive                     0.2       True
# 2                positive                     0.3       True
# 3                negative                    -0.2      False
# 4                positive                     0.2       True
# 5                positive                     0.3       True
# 6                negative                    -0.6       True
# 7                negative                    -0.1       True
# 8                 neutral                     0.0       True
# 9                 neutral                     0.0       True
# 10                neutral                     0.0      False
# 11               positive                     0.5       True
# 12               positive                     0.2       True
# 13                neutral                     0.0       True
# 14               negative                    -0.1       True
# 15               positive                     0.2       True
# 16               positive                     0.3       True
# 17               positive                     0.1       True
# 18               positive                     0.8       True
# 19               positive                     0.3      False
# 20               positive                     0.5       True
# 21               positive                     0.1       True
# 22               positive                     0.4       True
# 23                neutral                     0.0       True
# 24               positive                     0.3       True
# 25               positive                     0.2       True
# 26               positive                     0.5       True
# 27                neutral                     0.0       True
# 28                neutral                     0.0       True
# 29               positive                     0.1       True
# 30               positive                     0.1       True
# 31               negative                    -0.1       True
# 32               positive                     0.1       True
# 33               positive                     0.2       True
# 34               positive                     0.6       True
# 35                neutral                     0.0       True
# 36               positive                     0.2       True
# 37               negative                    -0.2       True
# 38               positive                     0.2       True
# 39               positive                     0.7       True
# 40               positive                     0.3      False
# 41               positive                     0.3       True
# 42               positive                     0.1       True
# 43               positive                     0.2       True
# 44               positive                     0.2       True
# 45               positive                     0.3       True
# 46               positive                     0.4       True
# 47               positive                     0.5      False
# 48               positive                     0.2       True
# 49                neutral                     0.0       True

# %%
# DataFrame with all the valid places:
mask = new_data['has_place'] == True
data_valid_places = new_data[mask]

# List with all valid places:
places_list = data_valid_places['place'].to_list()

# csvFile_places = str(input(">>> Enter name for the output csv file for the number of tweets per state (ex.: tweets-per-state.csv): "))
csvFile_places = 'tts-por-estado.csv'
separar_estados(places_list, csvFile_places)

count = pd.read_csv(csvFile_places) # tts-por-estado.csv
number_of_tts = count['tts_count'].sum()

print("Total de tweets com 'place' do Brasil: {}".format(number_of_tts))
# Out:
# Total de tweets com 'place' do Brasil: 8974

# %%
data_valid_places.shape[0]
# Out:
# 9497

# %% [markdown]
# ## Análise de RTs

# %%
new_data.drop(columns=['is_rt'], inplace=True)

# %%
tweets = new_data['original_text'].tolist()
tweets = [str(x) for x in tweets]

tweets_RT = sum(1 for x in tweets if x.count('RT @'))

print("Total de RTs : {}".format(tweets_RT))
print("Isso equivale a {:.2f}% do número total de tweets.".format(tweets_RT*100/len(tweets)))
print('---------------------------------------------------------')


is_rt = []
rt_pattern = 'RT @'
original_tts = new_data['original_text'].tolist()
for idx, item in enumerate(original_tts):
    string = str(item)
    if string.find(rt_pattern) == 0:
        is_rt.append(True)
    else:
        is_rt.append(False)

is_rt = pd.DataFrame(is_rt, columns=['is_rt'])
new_data_rt = pd.concat([new_data, is_rt], axis=1)
print(">>> New column 'is_rt' has been concatenated")
try:
    if new_data_rt['Unnamed: 0'].any():
        print('---------------------------------------------------------')
        print(">>> Droping column 'Unnamed: 0'")
        new_data_rt.drop(columns=['Unnamed: 0'], inplace=True)
except KeyError:
    pass
# Out:
# Total de RTs : 2
# Isso equivale a 0.02% do número total de tweets.
# ---------------------------------------------------------
# >>> New column 'is_rt' has been concatenated

# %%
fileName = str(csvFile[:-4]+'_new.csv')
new_data_rt.to_csv(fileName)
print(">>> New file '{}' has been created.".format(fileName))
# Out:
# >>> New file 'lais_new.csv' has been created.

# %%
new_data_rt.shape
# Out:
# (10886, 15)

# %%
new_data_rt.head(50)
# Out:
#     id                      created_at  \
# 0    1  Thu Mar 19 23:46:46 +0000 2020
# 1    2  Thu Mar 19 23:46:36 +0000 2020
# 2    3  Thu Mar 19 23:46:34 +0000 2020
# 3    4  Thu Mar 19 23:46:14 +0000 2020
# 4    5  Thu Mar 19 23:46:11 +0000 2020
# 5    6  Thu Mar 19 23:45:40 +0000 2020
# 6    7  Thu Mar 19 23:45:38 +0000 2020
# 7    8  Thu Mar 19 23:44:45 +0000 2020
# 8    9  Thu Mar 19 23:44:31 +0000 2020
# 18                                                NaN
# 19                                                NaN
# 20                                                NaN
# 21                                                NaN
# 22                                         quarentena
# 23                                         quarentena
# 24                                         quarentena
# 25                                         quarentena
# 26                      coronavirusbrasil, quarentena
# 27                                         quarentena
# 28  NaQuarentenaEu, quarentenadia3, quarentenou, q...
# 29                           fiqueemcasa, fiqueseguro
# 30                                                NaN
# 31                                                NaN
# 32       quarentena, QuarentenaAsCegas, covid19brasil
# 33  repost, FicaEmCasa, quarentena, cardib, corona...
# 34                      AoVivo, Instagram, Quarentena
# 35                         quarentena, punkrock, rock
# 36                                         quarentena
# 37                                         quarentena
# 38                                        fiqueemcasa
# 39                                                NaN
# 40                         xocorona, isolamento, dia1
# 41                                         quarentena
# 42                                                NaN
# 43                               Quaresma, quarentena
# 44                            pintoawards, quarentena
# 45                                                NaN
# 46                                                NaN
# 47   padreairtonfreire, fundaçãoterra, peairtonfreire
# 48  prevencao, ajuda, coronavirusbrazil, corona, p...
# 49                                         homeoffice
#
#                                 place  \
# 0                    São Paulo/Brazil
# 1              Rio de Janeiro, Brasil
# 2                              Brasil
# 3               Teresina Piauí Brasil
# 4                      Rio de Janeiro
# 5                   Fortaleza, Brasil
# 6                          RJ, Brasil
# 7                    Salvador, Brasil
# 8              Rio de Janeiro, Brasil
# 9                 Boa Vista/RR-Brasil
# 10        Av Angelica 2491, 14o andar
# 11      São Bernardo do Campo, Brasil
# 12             Belo Horizonte, Brasil
# 13                           Natal/RN
# 14            Brazil - Rio de Janeiro
# 15                             Brasil
# 16              Florianópolis, Brasil
# 17                     Ilhéus, Brasil
# 18                          São Paulo
# 19     Av.Campos Sáles, 1625 - Centro
# 20                   Fonseca, Niterói
# 21                    Vitória, Brazil
# 22                             Brasil
# 23            Buenos Aires, Argentina
# 24      São Bernardo do Campo, Brasil
# 25             Rio de Janeiro, Brasil
# 26                  São Paulo, Brasil
# 27                    Recife - Brazil
# 28                  Fortaleza, Brasil
# 29  RS, Centro-Oeste e Norte - Brasil
# 30             Belo Horizonte, Brasil
# 31                     São Paulo - SP
# 32                    Ibirité, Brasil
# 33                             Brasil
# 34               Brazil, São Paulo/SP
# 35                     Rio De Janeiro
# 36                   Fortaleza, Ceará
# 37            Rio de Janeiro, Brasil
# 38              Santo André-SP-Brasil
# 39                Jaguariúna / Brasil
# 40                  Blumenau/SC - BRA
# 41                          São Paulo
# 42                      Serra, Brasil
# 43                             Brasil
# 44                  Sao Paulo, Brazil
# 45             Belo Horizonte, Brasil
# 46         Rio de Janeiro, RJ, Brasil
# 47                         Garanhuns
# 48              São Paulo, SP, Brasil
# 49                     Palmas, Brazil
#
#                                place_coord_boundaries  sentiment_lais  \
# 0   [[-46.826039, -24.008814], [-46.365052, -24.00...               2
# 1                                                 NaN               2
# 2                                                 NaN               1
# 3                                                 NaN               1
# 4                                                 NaN               3
# 5                                                 NaN               2
# 6                                                 NaN               3
# 7                                                 NaN               1
# 8                                                 NaN               2
# 9                                                 NaN               1
# 10                                                NaN               2
# 11                                                NaN               2
# 12                                                NaN               1
# 13                                                NaN               2
# 14                                                NaN               3
# 15  [[-46.826039, -24.008814], [-46.365052, -24.00...               3
# 16                                                NaN               2
# 17                                                NaN               3
# 18  [[-46.826039, -24.008814], [-46.365052, -24.00...               3
# 19                                                NaN               3
# 20                                                NaN               3
# 21                                                NaN               1
# 22                                                NaN               3
# 23                                                NaN               2
# 24                                                NaN               3
# 25                                                NaN               3
# 26                                                NaN               2
# 27                                                NaN               3
# 28  [[-38.638212, -3.88818], [-38.401568, -3.88818...               3
# 29                                                NaN               3
# 30                                                NaN               1
# 31                                                NaN               2
# 32                                                NaN               2
# 33                                                NaN               3
# 34                                                NaN               3
# 35                                                NaN               3
# 36                                                NaN               2
# 37  [[-43.795449, -23.08302], [-43.0877068, -23.08...               1
# 38  [[-46.826039, -24.008814], [-46.365052, -24.00...               3
# 39  [[-47.102118, -22.750218], [-46.93054, -22.750...               3
# 40                                                NaN               3
# 41                                                NaN               3
# 42                                                NaN               3
# 43                                                NaN               2
# 44                                                NaN               3
# 45                                                NaN               2
# 46  [[-43.795449, -23.08302], [-43.0877068, -23.08...               2
# 47  [[-36.9482256, -8.670601], [-36.542507, -8.670...               3
# 48                                                NaN               3
# 49                                                NaN               3
#
#    sentiment_label_lais sentiment_label_luis  sentiment_score_luis  \
# 0               neutral             negative                  0.60
# 1               neutral             positive                  0.97
# 2              negative             negative                  0.66
# 3              negative             negative                  0.98
# 4              positive              neutral                  0.97
# 5               neutral              neutral                  0.86
# 6              positive             negative                  0.64
# 7              negative              neutral                  0.83
# 8               neutral              neutral                  0.61
# 9              negative              neutral                  0.72
# 10              neutral             negative                  0.74
# 11              neutral             positive                  0.51
# 12             negative              neutral                  0.81
# 13              neutral              neutral                  0.69
# 14             positive              neutral                  0.83
# 15             positive              neutral                  0.85
# 16              neutral              neutral                  0.72
# 17             positive              neutral                  0.90
# 18             positive             positive                  0.92
# 19             positive             positive                  0.96
# 20             positive             negative                  0.76
# 21             negative             negative                  0.89
# 22             positive             negative                  0.93
# 23              neutral              neutral                  0.72
# 24             positive              neutral                  0.93
# 25             positive              neutral                  0.74
# 26              neutral             positive                  0.91
# 27             positive             negative                  0.96
# 28             positive             negative                  0.91
# 29             positive             negative                  0.48
# 30             negative             positive                  0.96
# 31              neutral             negative                  0.92
# 32              neutral              neutral                  0.59
# 33             positive              neutral                  0.93
# 34             positive             negative                  0.94
# 35             positive             negative                  0.56
# 36              neutral              neutral                  0.78
# 37             negative             negative                  0.93
# 38             positive                mixed                 -1.00
# 39             positive             positive                  0.80
# 40             positive             positive                  0.92
# 41             positive             negative                  0.72
# 42             positive             negative                  0.88
# 43              neutral             negative                  0.44
# 44             positive              neutral                  0.90
# 45              neutral             positive                  0.99
# 46              neutral              neutral                  0.67
# 47             positive             negative                  0.74
# 48             positive              neutral                  0.93
# 49             positive             negative                  0.64
#
#    sentiment_label_google  sentiment_score_google  has_place  is_rt
# 0                positive                     0.4       True  False
# 1                positive                     0.2       True  False
# 2                positive                     0.3       True  False
# 3                negative                    -0.2      False  False
# 4                positive                     0.2       True  False
# 5                positive                     0.3       True  False
# 6                negative                    -0.6       True  False
# 7                negative                    -0.1       True  False
# 8                 neutral                     0.0       True  False
# 9                 neutral                     0.0       True  False
# 10                neutral                     0.0      False  False
# 11               positive                     0.5       True  False
# 12               positive                     0.2       True  False
# 13                neutral                     0.0       True  False
# 14               negative                    -0.1       True  False
# 15               positive                     0.2       True  False
# 16               positive                     0.3       True  False
# 17               positive                     0.1       True  False
# 18               positive                     0.8       True  False
# 19               positive                     0.3      False  False
# 20               positive                     0.5       True  False
# 21               positive                     0.1       True  False
# 22               positive                     0.4       True  False
# 23                neutral                     0.0       True  False
# 24               positive                     0.3       True  False
# 25               positive                     0.2       True  False
# 26               positive                     0.5       True  False
# 27                neutral                     0.0       True  False
# 28                neutral                     0.0       True  False
# 29               positive                     0.1       True  False
# 30               positive                     0.1       True  False
# 31               negative                    -0.1       True  False
# 32               positive                     0.1       True  False
# 33               positive                     0.2       True  False
# 34               positive                     0.6       True  False
# 35                neutral                     0.0       True  False
# 36               positive                     0.2       True  False
# 37               negative                    -0.2       True  False
# 38               positive                     0.2       True  False
# 39               positive                     0.7       True  False
# 40               positive                     0.3      False  False
# 41               positive                     0.3       True  False
# 42               positive                     0.1       True  False
# 43               positive                     0.2       True  False
# 44               positive                     0.2       True  False
# 45               positive                     0.3       True  False
# 46               positive                     0.4       True  False
# 47               positive                     0.5      False  False
# 48               positive                     0.2       True  False
# 49                neutral                     0.0       True  False

# %% [markdown]
# ## Lista para nuvem de palavras

# %%
mask = new_data_rt['is_rt'] == False
cloud_data = new_data_rt[mask]
mask = cloud_data['has_place'] == True
cloud_data = cloud_data[mask]

clean_tuites = cloud_data['original_text'].to_list()
clean_tuites = clean_tts(clean_tuites)

word_list = []
stop_words = ['e', 'de', 'a', 'as', 'da', 'das', 'o', 'os', 'aos', 'do', 'dos', 'que', 'em', 'com', 'para', 'n', 'no', 'na', 'um', 'se', 'pra', 'este', 'esta', 'pro', 'me', 'ao', 'ou', 'esse', 'essa', 'q', 'p', 'nas', 'pq', 'tao', 'entao', 'te', 'porque', '1', '2', '3', '4', '5', '7', '10', '...', '.', ',', '?', '!', '|', ':', '#', '@']
print(">>> Saving file 'nuvem_palavras.txt'...")
with open('nuvem_palavras.txt', 'w') as wf:
    for phrase in clean_tuites:
        for word in phrase.split():
            if word not in stop_words:
                if word[-1] == '.' or word[-1] == ',':
                    word_list.append(str(word[:-1]))
                else:
                    word_list.append(str(word))
                wf.write(word + ' ')

words_count = Counter(word_list)
df_words_count = pd.DataFrame(words_count.items(), columns=['word', 'count'])
df_words_count = df_words_count.sort_values(by=['count'], ascending=False).reset_index(drop=True)
print(">>> Saving file 'words_count.csv'...")
df_words_count.to_csv('words_count.csv')
# Out:
# >>> Saving file 'nuvem_palavras.txt'...
# >>> Saving file 'words_count.csv'...

# %% [raw]
# writer = pd.ExcelWriter('twitter_data.xlsx')
# twitter_data.to_excel(writer, 'DataFrame')
# writer.save()

# %% [markdown]
# ## Plotting number of tweets per day

# %%
dates = new_data_rt['created_at'].to_list()

clean_datas = []
for idx, item in enumerate(dates):
    string = str(item)
    day = string[8:10]
    month = string[4:7]
    if month == 'Apr':
        month = '04'
        clean_datas.append('{}-{}'.format(day, month))
    else:
        month = '03'
        clean_datas.append('{}-{}'.format(day, month))

counts = Counter(clean_datas)
df_num_tts = pd.DataFrame(counts.items(), columns=['created_at', 'num_tts'])
# df_num_tts.drop([0, 36], axis=0, inplace=True)
df_num_tts = df_num_tts.sort_values(by=['created_at']).reset_index(drop=True)

sns_plot = sns.lineplot(x="created_at", y="num_tts", data=df_num_tts)
sns_plot.set(xticks=[4, 9, 14, 19, 24, 29, 34])
sns_plot.set(xlabel="Data", ylabel = "Número de tweets")
fig = sns_plot.get_figure()
fig.savefig("tweets_per_day.png")

# %%
df_num_tts.head(50)
# Out:
#   created_at  num_tts
# 0      11-03        5
# 1      12-03       61
# 2      13-03      106
# 3      14-03      140
# 4      15-03      276
# 5      16-03     1018
# 6      17-03     3069
# 7      18-03     2760
# 8      19-03     3451

# %%
date = ['03-11', '03-12', '03-13', '03-14', '03-15', '03-16', '03-17', '03-18', '03-19', '03-20', '03-22', '03-23', '03-24', '03-25', '03-26', '03-27', '03-28', '03-29', '03-30', '04-01', '04-02', '04-03', '04-04', '04-05', '04-06', '04-07', '04-08', '04-09', '04-10', '04-11', '04-12', '04-13', '04-14', '04-15']
num_tts = [30, 147, 334, 1933, 2337, 5310, 28828, 19731, 22183, 9522, 12798, 13006, 31503, 24539, 45305, 21953, 36773, 30404, 24191, 7202, 2666, 16021, 17999, 45797, 43100, 15862, 15304, 21821, 20111, 11228, 4632, 23191, 14870, 7244]

# %%
df_num_tts = pd.DataFrame(columns=['date', 'num_tts'])
for i, j in zip(date, num_tts):
    row_to_app = [str(i), int(j)]
    row = pd.DataFrame([row_to_app], columns=['date', 'num_tts'])
    df_num_tts = df_num_tts.append(row, ignore_index=True)
df_num_tts.head(50)
# Out:
#      date num_tts
# 0   03-11      30
# 1   03-12     147
# 2   03-13     334
# 3   03-14    1933
# 4   03-15    2337
# 5   03-16    5310
# 6   03-17   28828
# 7   03-18   19731
# 8   03-19   22183
# 9   03-20    9522
# 10  03-22   12798
# 11  03-23   13006
# 12  03-24   31503
# 13  03-25   24539
# 14  03-26   45305
# 15  03-27   21953
# 16  03-28   36773
# 17  03-29   30404
# 18  03-30   24191
# 19  04-01    7202
# 20  04-02    2666
# 21  04-03   16021
# 22  04-04   17999
# 23  04-05   45797
# 24  04-06   43100
# 25  04-07   15862
# 26  04-08   15304
# 27  04-09   21821
# 28  04-10   20111
# 29  04-11   11228
# 30  04-12    4632
# 31  04-13   23191
# 32  04-14   14870
# 33  04-15    7244

# %%
sns_plot = sns.lineplot(x=date, y=num_tts)
sns_plot.set(xticks=[0, 5, 10, 15, 20, 25, 30, 35])
sns_plot.set(xlabel="Data", ylabel = "Número de tweets")
fig = sns_plot.get_figure()
fig.savefig("tweets_per_day.png")

# %% [markdown]
# ### Resultados preliminares totais do BERT (Google) e LUIS (Microsoft)

# %%
sns.countplot(new_data_rt['sentiment_label_lais'])
# new_data_rt sentiment_label_lais sentiment_label_luis sentiment_label_google

# %%
result_lais = new_data_rt.groupby(by=['sentiment_label_lais'])['sentiment_label_lais'].count()

# %%
result_lais
# Out:
# sentiment_label_lais
# negative    2319
# neutral     5995
# positive    2572
# Name: sentiment_label_lais, dtype: int64

# %%
result_lais['negative']
# Out:
# 2319

# %%
sns.countplot(new_data_rt['sentiment_label_google'])

# %%
result_google = new_data_rt.groupby(by=['sentiment_label_google'])['sentiment_label_google'].count()

# %%
result_google
# Out:
# sentiment_label_google
# negative    1577
# neutral     2138
# positive    7171
# Name: sentiment_label_google, dtype: int64

# %%
result_google['negative']
# Out:
# 1577

# %%
sns.countplot(new_data_rt['sentiment_label_luis'])

# %%
result_luis = new_data_rt.groupby(by=['sentiment_label_luis'])['sentiment_label_luis'].count()

# %%
result_luis
# Out:
# sentiment_label_luis
# mixed        334
# negative    3486
# neutral     4630
# positive    2436
# Name: sentiment_label_luis, dtype: int64

# %%
result_luis['negative']
# Out:
# 3486

# %% [markdown]
# ### Acurácia do BERT comparado aos dados base Lais

# %%
score_lais = {'negative' : 0, 'positive' : 0, 'neutral': 0}
for i,j in enumerate(new_data_rt['sentiment_label_lais']):
    if j == str(new_data_rt['sentiment_label_lais'].loc[i]):
        score_lais[j] += 1

# %%
score_lais
# Out:
# {'negative': 2319, 'positive': 2572, 'neutral': 5995}

# %%
score_lais.values()
# Out:
# dict_values([2319, 2572, 5995])

# %%
test_score_bert = {'negative' : 0, 'positive' : 0, 'neutral': 0}
for i,j in enumerate(new_data_rt['sentiment_label_lais']):
    if j == str(new_data_rt['sentiment_label_google'].loc[i]):
        test_score_bert[j] += 1

# %%
test_score_bert
# Out:
# {'negative': 745, 'positive': 2060, 'neutral': 1217}

# %%
test_score_bert_perc = {key : x/y for key, x in test_score_bert.items() for y in score_lais.values()}

# %%
test_score_bert_perc
# Out:
# {'negative': 0.12427022518765637,
#  'positive': 0.34361968306922436,
#  'neutral': 0.2030025020850709}

# %% [markdown]
# ### Acurácia do LUIS comparado aos dados base Lais

# %%
test_score_luis = {'negative' : 0, 'positive' : 0, 'neutral': 0}
for i,j in enumerate(new_data_rt['sentiment_label_lais']):
    if j == str(new_data_rt['sentiment_label_luis'].loc[i]):
        test_score_luis[j] += 1

# %%
test_score_luis
# Out:
# {'negative': 1310, 'positive': 1010, 'neutral': 3082}

# %%
test_score_luis_perc = {key : x/y for key, x in test_score_luis.items() for y in score_lais.values()}

# %%
test_score_luis_perc
# Out:
# {'negative': 0.21851542952460384,
#  'positive': 0.16847372810675562,
#  'neutral': 0.5140950792326939}
